# %% [markdown]
# # Ejercicio: Análisis de horas de uso de redes sociales
#
# Un grupo de estudiantes registró durante 30 días la **cantidad de horas que pasaron usando redes sociales**.
# Los datos están representados en una **Serie de Pandas**, donde cada índice corresponde al día (`Día 1`, `Día 2`, ..., `Día 30`).
#
# Su tarea será **analizar esta Serie** aplicando operaciones estadísticas y visualizaciones para entender mejor los hábitos de uso.
#
# ---
#
# ## Instrucciones
#
# 1. **Crear la Serie**
#
#    * Genera una lista de 30 valores (pueden ser aleatorios o inventados entre 0 y 10 horas).
#    * Convierte la lista en una Serie de Pandas.
#    * Usa como índice `Día 1`, `Día 2`, ..., `Día 30`.
#
# 2. **Exploración de la Serie**
#
#    * Muestra los primeros y últimos 5 valores.
#    * Consulta el valor de un día específico (por ejemplo, `"Día 7"`).
#    * Verifica la longitud, el tipo de datos y si existen valores faltantes.
#
# 3. **Estadísticas básicas**
#
#    * Calcula: promedio, mediana, mínimo, máximo, varianza y desviación estándar.
#    * Identifica los días con mayor y menor uso de redes sociales.
#
# 4. **Filtrado y condiciones**
#
#    * Filtra los días donde se usaron **más de 6 horas**.
#    * Cuenta cuántos días el uso fue **menor a 2 horas**.
#
#
# 5. **Visualizaciones**
#
#    * Realiza al menos **2 gráficos diferentes** para representar la información.
#    * Puedes elegir entre:
#
#      * Gráfico de línea para ver la evolución diaria.
#      * Histograma para la distribución de horas.
#      * Gráfico de barras para comparar ciertos días.
#    * ¡Se creativo! Elige los gráficos que mejor expliquen los resultados.

# %%
#Creacion de la serie
import random as rd
import pandas as pd

horas_redes= {f'Dia {i}':rd.randint(0,10) for i in range(1,31)}
serie_horas_redes=pd.Series(horas_redes,name="Horas usando redes sociales")
print(serie_horas_redes)
# Out:
# Dia 1     10
# Dia 2      5
# Dia 3      1
# Dia 4      4
# Dia 5      7
# Dia 6      2
# Dia 7      2
# Dia 8      2
# Dia 9      3
# Dia 10     2
# Dia 11     8
# Dia 12     8
# Dia 13     3
# Dia 14     3
# Dia 15     1
# Dia 16     2
# Dia 17     8
# Dia 18     6
# Dia 19     5
# Dia 20     3
# Dia 21     9
# Dia 22     5
# Dia 23     7
# Dia 24     9
# Dia 25     8
# Dia 26    10
# Dia 27     2
# Dia 28     1
# Dia 29     4
# Dia 30     2
# Name: Horas usando redes sociales, dtype: int64

# %%
#EXPLORACION DE LA SERIE

print(f"* Primeros 5 elementos:\n{ serie_horas_redes.iloc[:5]}")
print(f"\n * Ultimos 5 elementos:\n{ serie_horas_redes.iloc[-5:]}")

print(f"\n * Consulta del valor en un dia en específico 'Dia 5' : { serie_horas_redes.loc['Dia 5']}")

print("\n * Longitud de la serie: ",len(serie_horas_redes))
print("\n * Tipo de dato: ", serie_horas_redes.dtype)
print("\n ¿Existen valores faltantes?:", serie_horas_redes.isnull().any())
# Out:
# * Primeros 5 elementos:
# Dia 1    8
# Dia 2    1
# Dia 3    7
# Dia 4    2
# Dia 5    0
# Name: Horas usando redes sociales, dtype: int64
#
#  * Ultimos 5 elementos:
# Dia 26    7
# Dia 27    9
# Dia 28    2
# Dia 29    0
# Dia 30    3
# Name: Horas usando redes sociales, dtype: int64
#
#  * Consulta del valor en un dia en específico 'Dia 5' : 0
#
#  * Longitud de la serie:  30
#
#  * Tipo de dato:  int64
#
#  ¿Existen valores faltantes?: False

# %%
# Calcular estadísticas
media = serie_horas_redes.mean()
mediana = serie_horas_redes.median()
varianza = serie_horas_redes.var()
sd = serie_horas_redes.std()

print(f"\nEn promedio, los estudiantes utilizaron las redes sociales durante {int(media)} horas y {int((media - int(media)) * 60)} minutos al día.")
print(f"\nLa mediana fue de {int(mediana)} horas y {int((mediana - int(mediana)) * 60)} minutos al día.")
print(f"\nEl valor mayor fue de {serie_horas_redes.max()} horas en {serie_horas_redes.idxmax()} (primera coincidencia).")
print(f"\nEl valor menor fue de {serie_horas_redes.min()} horas en {serie_horas_redes.idxmin()} (primera coincidencia).")
print(f"\nLa varianza fue de {round(varianza, 4)} horas^2.")
print(f"\nLa desviación estándar fue de {round(sd, 4)} horas.")
# Out:
# En promedio, los estudiantes utilizaron las redes sociales durante 4 horas y 44 minutos al día.
#
# La mediana fue de 4 horas y 0 minutos al día.
#
# El valor mayor fue de 10 horas en Dia 1 (primera coincidencia).
#
# El valor menor fue de 1 horas en Dia 3 (primera coincidencia).
#
# La varianza fue de 8.754 horas^2.
#
# La desviación estándar fue de 2.9587 horas.

# %%
# Filtrado y condiciones.
dias_mas_6h = []
dias_menos_2h = []
print("\n* Dias con mas de 6 horas:")
for dia in serie_horas_redes.index:
  if serie_horas_redes[dia] > 6:
    print(dia, "->", serie_horas_redes[dia], "horas")
    dias_mas_6h.append(dia)

contador = 0
for dia in serie_horas_redes.index:
  if serie_horas_redes[dia] < 2:
    contador += 1
    dias_menos_2h.append(dia)

print(f"\n* Cantidad de dias con menos de 2h: {contador}")
# Out:
# * Dias con mas de 6 horas:
# Dia 1 -> 10 horas
# Dia 5 -> 7 horas
# Dia 11 -> 8 horas
# Dia 12 -> 8 horas
# Dia 17 -> 8 horas
# Dia 21 -> 9 horas
# Dia 23 -> 7 horas
# Dia 24 -> 9 horas
# Dia 25 -> 8 horas
# Dia 26 -> 10 horas
#
# * Cantidad de dias con menos de 2h: 3

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#Creando un estilo
plt.style.use('seaborn-v0_8')
#Creando las cuadriculas
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots (2,2,figsize =(20,10))

#Titulo
fig.suptitle("Analisis de uso de las redes sociales", fontsize=14, fontweight = "bold")

#Grafica 1
ax1.fill_between(serie_horas_redes.index, serie_horas_redes.values, color="skyblue", alpha=0.5)
ax1.plot(serie_horas_redes.index, serie_horas_redes.values, marker="o", color="blue")
ax1.set_title("Evolución diaria (Área)", fontsize=14, fontweight="bold")
ax1.set_ylabel("Horas",fontsize=14, fontweight="bold")
ax1.tick_params(axis="x", rotation=60)

#Grafica 2
ax2.hist(serie_horas_redes, bins=10, edgecolor='black', color='teal')
ax2.set_title("Distribución de Horas Diarias (Frecuencia)",fontsize=14, fontweight="bold")
ax2.set_xlabel("Rango de Horas de Uso",fontsize=14, fontweight="bold")
ax2.set_ylabel("Número de Días",fontsize=14, fontweight="bold")

#Grafica 3
datos_alto_uso = serie_horas_redes.loc[dias_mas_6h]
datos_alto_uso_sorted = datos_alto_uso.sort_values()
datos_alto_uso_sorted.plot(kind="barh",ax=ax3,color='coral' )

#Colocar la etiqueta de las horas
for index, value in enumerate(datos_alto_uso_sorted.values):
    # Colocar la etiqueta de las horas dentro o al lado de cada barra
    ax3.text(value - 0.5, index, f'{value}h', va='center', color='black', fontweight='bold')

ax3.set_title("Comparativa de Días de Alto Consumo (> 6h)", fontsize=14, fontweight="bold")
ax3.set_xlabel("Horas de Uso",fontsize=14, fontweight="bold")
ax3.set_ylabel("Día",fontsize=14, fontweight="bold")

# Ajusta automáticamente los espacios entre subplots para que no se encimen
plt.tight_layout()
# Muestra la figura completa en pantalla
plt.show()
